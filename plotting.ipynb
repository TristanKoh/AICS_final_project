# %%
import pandas as pd

df_time_vals = pd.read_csv("time_vals.csv")

# %%
df_time_vals
# Out:
#    register_and_add  store_data  retrieve_data  peer_trust_rating  \
# 0          3.500249    0.033248       0.026882           0.389722
# 1          6.980474    0.061895       0.053067           1.404174
# 2         34.514476    0.275006       0.302167          34.790577
# 3         69.430792    0.571819       0.516914         177.196218
#
#    calculate_EigenTrust  add_block  num_peers
# 0              0.091563   0.190075        500
# 1              0.262931   0.651867       1000
# 2              5.910094  15.147276       5000
# 3             25.512686  56.708919      10000

# %%
df_time_vals.plot("num_peers", "register_and_add", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Register and add N peers")
# Out:
# <Axes: title={'center': 'Register and add N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_time_vals.plot("num_peers", ["store_data", "retrieve_data"], marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Store and retrieve data from N peers")
# Out:
# <Axes: title={'center': 'Store and retrieve data from N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_time_vals.plot("num_peers", "peer_trust_rating", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Peer providing trust ratings for N peers")
# Out:
# <Axes: title={'center': 'Peer providing trust ratings for N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_time_vals.plot("num_peers", "calculate_EigenTrust", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Calculate EigenTrust from N peers")
# Out:
# <Axes: title={'center': 'Calculate EigenTrust from N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_time_vals.plot("num_peers", "add_block", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Add block to blockchain N peers")
# Out:
# <Axes: title={'center': 'Add block to blockchain N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
import pandas as pd

df_avg_time_vals = pd.read_csv("avg_time_vals.csv")

# %%
df_avg_time_vals
# Out:
#    register_and_add  store_data  retrieve_data  peer_trust_rating  \
# 0          0.007000    0.000066       0.000054           0.000779
# 1          0.006980    0.000062       0.000053           0.001404
# 2          0.006903    0.000055       0.000060           0.006958
# 3          0.006943    0.000057       0.000052           0.017720
#
#    calculate_EigenTrust  add_block  num_peers
# 0              0.000183   0.000380        500
# 1              0.000263   0.000652       1000
# 2              0.001182   0.003029       5000
# 3              0.002551   0.005671      10000

# %%
df_avg_time_vals.plot("num_peers", "register_and_add", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Register and add N peers", ylim = (0.006, 0.00750))
# Out:
# <Axes: title={'center': 'Register and add N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_avg_time_vals.plot("num_peers", ["store_data", "retrieve_data"], marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Register and add N peers", ylim = (5e-5, 7e-5))
# Out:
# <Axes: title={'center': 'Register and add N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_avg_time_vals.plot("num_peers", "peer_trust_rating", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Provide trust ratings N peers")
# Out:
# <Axes: title={'center': 'Provide trust ratings N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_avg_time_vals.plot("num_peers", "calculate_EigenTrust", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Calculate EigenTrust N peers")
# Out:
# <Axes: title={'center': 'Calculate EigenTrust N peers'}, xlabel='N peers', ylabel='seconds'>

# %%
df_avg_time_vals.plot("num_peers", "add_block", marker = "x", 
                  figsize = (4, 3), 
                  ylabel = "seconds", xlabel = "N peers", 
                  title = "Add block to blockchain")
# Out:
# <Axes: title={'center': 'Add block to blockchain'}, xlabel='N peers', ylabel='seconds'>
